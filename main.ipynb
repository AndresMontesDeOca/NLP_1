# %% [markdown]
# <a href="https://colab.research.google.com/github/AndresMontesDeOca/NLP_1/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import userdata

# 1. Obtener el token de los Secretos de Colab
try:
    GITHUB_TOKEN = userdata.get('GITHUB_TOKEN')
except userdata.SecretNotFoundError:
    print("Error: No se encontró el secreto 'GITHUB_TOKEN'.")

# 2. Clonar tu repositorio (solo si la carpeta no existe en esta sesión de Colab)
if not os.path.exists('procesamiento_lenguaje_natural'):
    print("Clonando el repositorio...")
    # !git clone https://{GITHUB_TOKEN}@github.com/AndresMontesDeOca/NLP_1.git procesamiento_lenguaje_natural

# 3. Entrar a la carpeta de trabajo
# %cd procesamiento_lenguaje_natural

# 4. Configurar tus credenciales de Git
# !git config --global user.email "amontesdeoca1982@gmail.com"
# !git config --global user.name "AndresMontesDeOca"

# 5. Conectar con el repositorio de la materia (ignora el error si ya existe)
# !git remote add upstream https://github.com/FIUBA-Posgrado-Inteligencia-Artificial/procesamiento_lenguaje_natural.git 2> /dev/null || true

# 6. --- LA RUTINA DE ACTUALIZACIÓN ---
print("\nBuscando actualizaciones de la profesora...")
# !git pull upstream main

print("\nGuardando todo en tu GitHub...")
# !git push origin main
# Out:
# Clonando el repositorio...
# Cloning into 'procesamiento_lenguaje_natural'...
# remote: Enumerating objects: 1559, done.
# remote: Total 1559 (delta 0), reused 0 (delta 0), pack-reused 1559 (from 1)
# Receiving objects: 100% (1559/1559), 61.21 MiB | 41.73 MiB/s, done.
# Resolving deltas: 100% (826/826), done.
# /content/procesamiento_lenguaje_natural/procesamiento_lenguaje_natural
#
# Buscando actualizaciones de la profesora...
# From https://github.com/FIUBA-Posgrado-Inteligencia-Artificial/procesamiento_lenguaje_natural
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> upstream/main
# Already up to date.
#
# Guardando todo en tu GitHub...
# Everything up-to-date
